# %%
class EnglishDictionary:
    def ___int___(self):
        self.dictionary = {}
        
    def add__word(self, word, meaning):
        self.dictionary = meaning
        print(f"'{word}' added to the dictionary.")
    
    def search__word(self, word):
        if word in self.dictionary:
            print(f"Meaning of '{word}': {self.dictionary[word]}")
        else:
            print(f"'{word}' not found in the dictionary")
            
    def update__meaning(self, word, meaning):
        if word in self.dictionary:
            self.dictionary = new_meaning
            print(f"Meaning of '{word}' update.")
        else:
            print(f"'{word}' not found in the dictionary.")
            
    def display__dictionary(self):
        print("Dictionary")
        for word, meaning in self.dictionary.items():
            print(f"{word}: {meaning}")
            
            
dictionary = EnglishDictionary()    
    
while True:
    print("1. Add a word")
    print("2. Update meaning")
    print("3. Search word")
    print("4. Display dictionary")
    print("5. Exit")

    choice = input("Enter your choice:")



    if choice == '1':
        word = input("enter the word:")
        meaning = input("Enter the meaning:")
        dictionary.add__word(word, meaning)
    elif choice == '2':
        word = input("Enter the word whose meaning you want to update:")
        new_meaning = input("Enter the new meaning:")
        dictionary.update__meaning(word, new_meaning)
    elif choice == '3':
        word = input("Enter the word to search:")
        dictionary.search__word(word)
    elif choice == '4':
        dictionary.display__dictionary()
    elif choice == '5':
        print("Existing program")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# 1. Add a word
# 2. Update meaning
# 3. Search word
# 4. Display dictionary
# 5. Exit
# Enter your choice:animal
# Invalid choice. Please try again.
# 1. Add a word
# 2. Update meaning
# 3. Search word
# 4. Display dictionary
# 5. Exit
# Enter your choice:1
# enter the word:animal
# Enter the meaning:. a creature that is not a bird, a fish, an insect or a human.
# 'animal' added to the dictionary.
# 1. Add a word
# 2. Update meaning
# 3. Search word
# 4. Display dictionary
# 5. Exit
# Enter your choice:2
# Enter the word whose meaning you want to update:indentation
# Enter the new meaning:occurs when the number of spaces at the beginning of a block is not equal to the number of spaces assigned at the end.
# 'indentation' not found in the dictionary.
# 1. Add a word
# 2. Update meaning
# 3. Search word
# 4. Display dictionary
# 5. Exit
# Enter your choice:3
# Enter the word to search:tamilnadu
# 'tamilnadu' not found in the dictionary
# 1. Add a word
# 2. Update meaning
# ...
